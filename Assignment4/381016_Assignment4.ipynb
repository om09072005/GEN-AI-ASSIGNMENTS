# %%
# !pip install openai --quiet

# %%
import os
from getpass import getpass

os.environ["CLARIFAI_PAT"] = getpass("Enter your Clarifai API key: ")
# Out:
# Enter your Clarifai API key: ··········

# %%
from openai import OpenAI

client = OpenAI(
    base_url="https://api.clarifai.com/v2/ext/openai/v1",
    api_key=os.environ["CLARIFAI_PAT"],
)

# conversation memory
messages = [
    {"role": "system", "content": "You are a helpful question-answering assistant."}
]

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Bot: Goodbye!")
        break

    messages.append({"role": "user", "content": user_input})

    response = client.chat.completions.create(
        model="https://clarifai.com/openai/chat-completion/models/gpt-oss-20b",
        messages=messages,
        temperature=0.5
    )

    bot_reply = response.choices[0].message.content
    print("Bot:", bot_reply)

    messages.append({"role": "assistant", "content": bot_reply})
# Out:
# You: hello
# Bot: Hello! How can I help you today?
# You: who are you
# Bot: I’m ChatGPT, a large language model created by OpenAI. I’m here to help answer questions, provide information, and chat about a wide range of topics. How can I assist you today?
# You: what is youe name
# Bot: I’m ChatGPT, the AI language model developed by OpenAI. Feel free to ask me anything!
# You: tell me your featured
# Bot: Here’s a quick rundown of the main features and capabilities that make ChatGPT useful for a wide range of tasks:
#
# | Feature | What it does | Typical use cases |
# |---------|--------------|-------------------|
# | **Conversational AI** | Understands and generates natural language in a back‑and‑forth dialogue. | Customer support, tutoring, brainstorming, casual chat. |
# | **Contextual Understanding** | Keeps track of the conversation context (within a session) to provide relevant answers. | Multi‑step problem solving, detailed explanations, follow‑up questions. |
# | **Knowledge Retrieval** | Pulls from a vast dataset of text up to its cutoff (2024‑06) to answer factual questions. | Quick facts, historical info, science explanations. |
# | **Creative Writing** | Generates stories, poems, scripts, marketing copy, and more. | Content creation, creative brainstorming, copywriting. |
# | **Code Generation & Debugging** | Writes, explains, and refactors code in many programming languages. | Learning programming, building prototypes, debugging help. |
# | **Summarization** | Condenses long texts into concise summaries. | Meeting notes, article summaries, executive briefs. |
# | **Translation** | Translates text between multiple languages. | Multilingual communication, language learning. |
# | **Formatting & Editing** | Improves grammar, style, and structure of text. | Academic writing, resumes, emails. |
# | **Data Analysis Guidance** | Explains statistical concepts, helps design experiments, interprets results. | Research, data science, business analytics. |
# | **Learning & Tutoring** | Provides explanations, practice problems, and study plans. | School subjects, exam prep, skill acquisition. |
# | **Role‑playing & Simulation** | Assumes personas or simulates scenarios. | Training, scenario planning, creative exploration. |
# | **Custom Instructions** | Users can give high‑level instructions to tailor responses. | Brand voice, tone preferences, specific formats. |
#
# **How to get the most out of ChatGPT**
#
# 1. **Be specific** – The clearer your question, the better the answer.
# 2. **Iterate** – If the first response isn’t perfect, ask follow‑up questions or request clarification.
# 3. **Use prompts** – Try prompt templates (e.g., “Explain like I’m five,” “Generate a marketing headline”) to guide the style.
# 4. **Check critical facts** – While I strive for accuracy, double‑check important data from reliable sources.
#
# If you have a particular task in mind, let me know and I can show you how to craft a prompt that gets the best result!
# You: exit
# Bot: Goodbye!
